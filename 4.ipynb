# %% [markdown]
# <a href="https://colab.research.google.com/github/dangogit/ML_HW3/blob/main/4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Obtaining and preparing the MNIST dataset

# %% [markdown]
# The MNIST dataset is publicly available at http://yann.lecun.com/exdb/mnist/ and consists of the following four parts:
#
# - Training set images: train-images-idx3-ubyte.gz (9.9 MB, 47 MB unzipped, 60,000 examples)
# - Training set labels: train-labels-idx1-ubyte.gz (29 KB, 60 KB unzipped, 60,000 labels)
# - Test set images: t10k-images-idx3-ubyte.gz (1.6 MB, 7.8 MB, 10,000 examples)
# - Test set labels: t10k-labels-idx1-ubyte.gz (5 KB, 10 KB unzipped, 10,000 labels)

# %%
from sklearn.datasets import fetch_openml


X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
X = X.values
y = y.astype(int).values

print(X.shape)
print(y.shape)
# Out:
# (70000, 784)
# (70000,)

# %% [markdown]
# Normalize to [-1, 1] range:

# %%
X = ((X / 255.) - .5) * 2

# %% [markdown]
# Visualize the first digit of each class:

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=2, ncols=5, sharex=True, sharey=True)
ax = ax.flatten()
for i in range(10):
    img = X[y == i][0].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
#plt.savefig('figures/11_4.png', dpi=300)
plt.show()

# %% [markdown]
# Visualize 25 different versions of "7":

# %%
fig, ax = plt.subplots(nrows=5, ncols=5, sharex=True, sharey=True)
ax = ax.flatten()
for i in range(25):
    img = X[y == 7][i].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
# plt.savefig('figures/11_5.png', dpi=300)
plt.show()

# %% [markdown]
# Split into training, validation, and test set:

# %%
from sklearn.model_selection import train_test_split


X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=10000, random_state=123, stratify=y)

X_train, X_valid, y_train, y_valid = train_test_split(
    X_temp, y_temp, train_size=0.7, test_size=0.3, random_state=123, stratify=y_temp)


# optional to free up some memory by deleting non-used arrays:
del X_temp, y_temp, X, y

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## Keras ANN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(50, input_dim=28*28, activation='relu'))
model.add(Dense(40, activation='relu'))
model.add(Dense(10, activation='softmax'))

l = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile(loss=l, optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Keras ANN Coding the neural network training loop and Evaluating the neural network performance

# %% [markdown]
# Defining data loaders:

# %%
import numpy as np

num_epochs = 50
minibatch_size = 100


def minibatch_generator(X, y, minibatch_size):
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    for start_idx in range(0, indices.shape[0] - minibatch_size 
                           + 1, minibatch_size):
        batch_idx = indices[start_idx:start_idx + minibatch_size]
        
        yield X[batch_idx], y[batch_idx]

        
# iterate over training epochs
for i in range(num_epochs):

    # iterate over minibatches
    minibatch_gen = minibatch_generator(
        X_train, y_train, minibatch_size)
    
    for X_train_mini, y_train_mini in minibatch_gen:

        break
        
    break
    
print(X_train_mini.shape)
print(y_train_mini.shape)
# Out:
# (100, 784)
# (100,)

# %% [markdown]
# Defining a function to compute the loss and accuracy

# %%
def mse_loss(targets, probas, num_labels=10):
    onehot_targets = int_to_onehot(targets, num_labels=num_labels)
    return np.mean((onehot_targets - probas)**2)


def accuracy(targets, predicted_labels):
    return np.mean(predicted_labels == targets) 

probas = model.predict(X_valid)
mse = mse_loss(y_valid, probas)

predicted_labels = np.argmax(probas, axis=1)
acc = accuracy(y_valid, predicted_labels)

print(f'Initial validation MSE: {mse:.1f}')
print(f'Initial validation accuracy: {acc*100:.1f}%')
# Out:
# Initial validation MSE: 0.1
# Initial validation accuracy: 12.8%

# %%
def compute_mse_and_acc(nnet, X, y, num_labels=10, minibatch_size=100):
    mse, correct_pred, num_examples = 0., 0, 0
    minibatch_gen = minibatch_generator(X, y, minibatch_size)
        
    for i, (features, targets) in enumerate(minibatch_gen):

        probas = nnet.predict(features)
        predicted_labels = np.argmax(probas, axis=1)
        
        onehot_targets = int_to_onehot(targets, num_labels=num_labels)
        loss = np.mean((onehot_targets - probas)**2)
        correct_pred += (predicted_labels == targets).sum()
        
        num_examples += targets.shape[0]
        mse += loss

    mse = mse/i
    acc = correct_pred/num_examples
    return mse, acc

# %%
mse, acc = compute_mse_and_acc(model, X_valid, y_valid)
print(f'Initial valid MSE: {mse:.1f}')
print(f'Initial valid accuracy: {acc*100:.1f}%')
# Out:
# Initial valid MSE: 0.1
# Initial valid accuracy: 12.8%

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=100)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 420/420 [==============================] - 2s 4ms/step - loss: 0.5669 - accuracy: 0.8278
# Epoch 2/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.2796 - accuracy: 0.9156
# Epoch 3/50
# 420/420 [==============================] - 2s 5ms/step - loss: 0.2213 - accuracy: 0.9326
# Epoch 4/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.1898 - accuracy: 0.9421
# Epoch 5/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.1651 - accuracy: 0.9495
# Epoch 6/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.1503 - accuracy: 0.9542
# Epoch 7/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.1381 - accuracy: 0.9572
# Epoch 8/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.1320 - accuracy: 0.9589
# Epoch 9/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.1225 - accuracy: 0.9620
# Epoch 10/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.1157 - accuracy: 0.9637
# Epoch 11/50
# 420/420 [==============================] - 1s 3ms/step - loss: 0.1097 - accuracy: 0.9659
# Epoch 12/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.1053 - accuracy: 0.9674
# Epoch 13/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.1020 - accuracy: 0.9680
# Epoch 14/50
# 420/420 [==============================] - 1s 4ms/step - loss: 0.0962 - accuracy: 0.9703
# Epoch 15/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0921 - accuracy: 0.9706
# Epoch 16/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0891 - accuracy: 0.9713
# Epoch 17/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0853 - accuracy: 0.9737
# Epoch 18/50
# 420/420 [==============================] - 2s 5ms/step - loss: 0.0797 - accuracy: 0.9743
# Epoch 19/50
# 420/420 [==============================] - 1s 4ms/step - loss: 0.0785 - accuracy: 0.9756
# Epoch 20/50
# 420/420 [==============================] - 1s 4ms/step - loss: 0.0741 - accuracy: 0.9770
# Epoch 21/50
# 420/420 [==============================] - 1s 3ms/step - loss: 0.0777 - accuracy: 0.9747
# Epoch 22/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0680 - accuracy: 0.9785
# Epoch 23/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0684 - accuracy: 0.9769
# Epoch 24/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0666 - accuracy: 0.9781
# Epoch 25/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0673 - accuracy: 0.9783
# Epoch 26/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0631 - accuracy: 0.9795
# Epoch 27/50
# 420/420 [==============================] - 1s 4ms/step - loss: 0.0618 - accuracy: 0.9796
# Epoch 28/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0570 - accuracy: 0.9813
# Epoch 29/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0544 - accuracy: 0.9825
# Epoch 30/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0537 - accuracy: 0.9822
# Epoch 31/50
# 420/420 [==============================] - 1s 3ms/step - loss: 0.0537 - accuracy: 0.9822
# Epoch 32/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0515 - accuracy: 0.9824
# Epoch 33/50
# 420/420 [==============================] - 1s 3ms/step - loss: 0.0515 - accuracy: 0.9832
# Epoch 34/50
# 420/420 [==============================] - 1s 4ms/step - loss: 0.0478 - accuracy: 0.9841
# Epoch 35/50
# 420/420 [==============================] - 1s 3ms/step - loss: 0.0477 - accuracy: 0.9840
# Epoch 36/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0454 - accuracy: 0.9848
# Epoch 37/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0433 - accuracy: 0.9854
# Epoch 38/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0451 - accuracy: 0.9847
# Epoch 39/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0426 - accuracy: 0.9854
# Epoch 40/50
# 420/420 [==============================] - 1s 3ms/step - loss: 0.0431 - accuracy: 0.9854
# Epoch 41/50
# 420/420 [==============================] - 1s 3ms/step - loss: 0.0405 - accuracy: 0.9860
# Epoch 42/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0391 - accuracy: 0.9860
# Epoch 43/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0370 - accuracy: 0.9875
# Epoch 44/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0381 - accuracy: 0.9871
# Epoch 45/50
# 420/420 [==============================] - 1s 4ms/step - loss: 0.0353 - accuracy: 0.9874
# Epoch 46/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0321 - accuracy: 0.9890
# Epoch 47/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0336 - accuracy: 0.9884
# Epoch 48/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0318 - accuracy: 0.9890
# Epoch 49/50
# 420/420 [==============================] - 1s 4ms/step - loss: 0.0348 - accuracy: 0.9877
# Epoch 50/50
# 420/420 [==============================] - 2s 4ms/step - loss: 0.0305 - accuracy: 0.9899

# %%
test_mse, test_acc = compute_mse_and_acc(model, X_test, y_test)
print(f'Test accuracy: {test_acc*100:.2f}%')
# Out:
# Test accuracy: 96.04%

# %% [markdown]
# Plot failure cases:

# %%
X_test_subset = X_test[:1000, :]
y_test_subset = y_test[:1000]

probas = model.predict(X_test_subset)
test_pred = np.argmax(probas, axis=1)

misclassified_images = X_test_subset[y_test_subset != test_pred][:25]
misclassified_labels = test_pred[y_test_subset != test_pred][:25]
correct_labels = y_test_subset[y_test_subset != test_pred][:25]

# %%
fig, ax = plt.subplots(nrows=5, ncols=5, 
                       sharex=True, sharey=True, figsize=(8, 8))
ax = ax.flatten()
for i in range(25):
    img = misclassified_images[i].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys', interpolation='nearest')
    ax[i].set_title(f'{i+1}) '
                    f'True: {correct_labels[i]}\n'
                    f' Predicted: {misclassified_labels[i]}')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
#plt.savefig('figures/11_09.png', dpi=300)
plt.show()

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## Implementing a multi-layer perceptron

# %%
import numpy as np

# %%
##########################
### MODEL
##########################

def sigmoid(z):                                        
    return 1. / (1. + np.exp(-z))


def int_to_onehot(y, num_labels):

    ary = np.zeros((y.shape[0], num_labels))
    for i, val in enumerate(y):
        ary[i, val] = 1

    return ary


class NeuralNetMLP:

    def __init__(self, num_features, num_hidden, num_classes, random_seed=123):
        super().__init__()
        
        self.num_classes = num_classes
        
        # hidden
        rng = np.random.RandomState(random_seed)
        
        self.weight_h = rng.normal(
            loc=0.0, scale=0.1, size=(num_hidden, num_features))
        self.bias_h = np.zeros(num_hidden)
        
        # output
        self.weight_out = rng.normal(
            loc=0.0, scale=0.1, size=(num_classes, num_hidden))
        self.bias_out = np.zeros(num_classes)
        
    def forward(self, x):
        # Hidden layer
        # input dim: [n_examples, n_features] dot [n_hidden, n_features].T
        # output dim: [n_examples, n_hidden]
        z_h = np.dot(x, self.weight_h.T) + self.bias_h
        a_h = sigmoid(z_h)

        # Output layer
        # input dim: [n_examples, n_hidden] dot [n_classes, n_hidden].T
        # output dim: [n_examples, n_classes]
        z_out = np.dot(a_h, self.weight_out.T) + self.bias_out
        a_out = sigmoid(z_out)
        return a_h, a_out

    def backward(self, x, a_h, a_out, y):  
    
        #########################
        ### Output layer weights
        #########################
        
        # onehot encoding
        y_onehot = int_to_onehot(y, self.num_classes)

        # Part 1: dLoss/dOutWeights
        ## = dLoss/dOutAct * dOutAct/dOutNet * dOutNet/dOutWeight
        ## where DeltaOut = dLoss/dOutAct * dOutAct/dOutNet
        ## for convenient re-use
        
        # input/output dim: [n_examples, n_classes]
        d_loss__d_a_out = 2.*(a_out - y_onehot) / y.shape[0]

        # input/output dim: [n_examples, n_classes]
        d_a_out__d_z_out = a_out * (1. - a_out) # sigmoid derivative

        # output dim: [n_examples, n_classes]
        delta_out = d_loss__d_a_out * d_a_out__d_z_out # "delta (rule) placeholder"

        # gradient for output weights
        
        # [n_examples, n_hidden]
        d_z_out__dw_out = a_h
        
        # input dim: [n_classes, n_examples] dot [n_examples, n_hidden]
        # output dim: [n_classes, n_hidden]
        d_loss__dw_out = np.dot(delta_out.T, d_z_out__dw_out)
        d_loss__db_out = np.sum(delta_out, axis=0)
        

        #################################        
        # Part 2: dLoss/dHiddenWeights
        ## = DeltaOut * dOutNet/dHiddenAct * dHiddenAct/dHiddenNet * dHiddenNet/dWeight
        
        # [n_classes, n_hidden]
        d_z_out__a_h = self.weight_out
        
        # output dim: [n_examples, n_hidden]
        d_loss__a_h = np.dot(delta_out, d_z_out__a_h)
        
        # [n_examples, n_hidden]
        d_a_h__d_z_h = a_h * (1. - a_h) # sigmoid derivative
        
        # [n_examples, n_features]
        d_z_h__d_w_h = x
        
        # output dim: [n_hidden, n_features]
        d_loss__d_w_h = np.dot((d_loss__a_h * d_a_h__d_z_h).T, d_z_h__d_w_h)
        d_loss__d_b_h = np.sum((d_loss__a_h * d_a_h__d_z_h), axis=0)

        return (d_loss__dw_out, d_loss__db_out, 
                d_loss__d_w_h, d_loss__d_b_h)

# %%
model = NeuralNetMLP(num_features=28*28,
                     num_hidden=50,
                     num_classes=10)

# %% [markdown]
# ## Coding the neural network training loop

# %% [markdown]
# Defining data loaders:

# %%
import numpy as np

num_epochs = 50
minibatch_size = 100


def minibatch_generator(X, y, minibatch_size):
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    for start_idx in range(0, indices.shape[0] - minibatch_size 
                           + 1, minibatch_size):
        batch_idx = indices[start_idx:start_idx + minibatch_size]
        
        yield X[batch_idx], y[batch_idx]

        
# iterate over training epochs
for i in range(num_epochs):

    # iterate over minibatches
    minibatch_gen = minibatch_generator(
        X_train, y_train, minibatch_size)
    
    for X_train_mini, y_train_mini in minibatch_gen:

        break
        
    break
    
print(X_train_mini.shape)
print(y_train_mini.shape)
# Out:
# (100, 784)
# (100,)

# %% [markdown]
# Defining a function to compute the loss and accuracy

# %%
def mse_loss(targets, probas, num_labels=10):
    onehot_targets = int_to_onehot(targets, num_labels=num_labels)
    return np.mean((onehot_targets - probas)**2)


def accuracy(targets, predicted_labels):
    return np.mean(predicted_labels == targets) 


_, probas = model.forward(X_valid)
mse = mse_loss(y_valid, probas)

predicted_labels = np.argmax(probas, axis=1)
acc = accuracy(y_valid, predicted_labels)

print(f'Initial validation MSE: {mse:.1f}')
print(f'Initial validation accuracy: {acc*100:.1f}%')
# Out:
# Initial validation MSE: 0.3
# Initial validation accuracy: 9.2%

# %%
def compute_mse_and_acc(nnet, X, y, num_labels=10, minibatch_size=100):
    mse, correct_pred, num_examples = 0., 0, 0
    minibatch_gen = minibatch_generator(X, y, minibatch_size)
        
    for i, (features, targets) in enumerate(minibatch_gen):

        _, probas = nnet.forward(features)
        predicted_labels = np.argmax(probas, axis=1)
        
        onehot_targets = int_to_onehot(targets, num_labels=num_labels)
        loss = np.mean((onehot_targets - probas)**2)
        correct_pred += (predicted_labels == targets).sum()
        
        num_examples += targets.shape[0]
        mse += loss

    mse = mse/i
    acc = correct_pred/num_examples
    return mse, acc

# %%
mse, acc = compute_mse_and_acc(model, X_valid, y_valid)
print(f'Initial valid MSE: {mse:.1f}')
print(f'Initial valid accuracy: {acc*100:.1f}%')
# Out:
# Initial valid MSE: 0.3
# Initial valid accuracy: 9.2%

# %%
def train(model, X_train, y_train, X_valid, y_valid, num_epochs,
          learning_rate=0.1):
    
    epoch_loss = []
    epoch_train_acc = []
    epoch_valid_acc = []
    
    for e in range(num_epochs):

        # iterate over minibatches
        minibatch_gen = minibatch_generator(
            X_train, y_train, minibatch_size)

        for X_train_mini, y_train_mini in minibatch_gen:
            
            #### Compute outputs ####
            a_h, a_out = model.forward(X_train_mini)

            #### Compute gradients ####
            d_loss__d_w_out, d_loss__d_b_out, d_loss__d_w_h, d_loss__d_b_h = \
                model.backward(X_train_mini, a_h, a_out, y_train_mini)

            #### Update weights ####
            model.weight_h -= learning_rate * d_loss__d_w_h
            model.bias_h -= learning_rate * d_loss__d_b_h
            model.weight_out -= learning_rate * d_loss__d_w_out
            model.bias_out -= learning_rate * d_loss__d_b_out
        
        #### Epoch Logging ####        
        train_mse, train_acc = compute_mse_and_acc(model, X_train, y_train)
        valid_mse, valid_acc = compute_mse_and_acc(model, X_valid, y_valid)
        train_acc, valid_acc = train_acc*100, valid_acc*100
        epoch_train_acc.append(train_acc)
        epoch_valid_acc.append(valid_acc)
        epoch_loss.append(train_mse)
        print(f'Epoch: {e+1:03d}/{num_epochs:03d} '
              f'| Train MSE: {train_mse:.2f} '
              f'| Train Acc: {train_acc:.2f}% '
              f'| Valid Acc: {valid_acc:.2f}%')

    return epoch_loss, epoch_train_acc, epoch_valid_acc

# %%
np.random.seed(123) # for the training set shuffling

epoch_loss, epoch_train_acc, epoch_valid_acc = train(
    model, X_train, y_train, X_valid, y_valid,
    num_epochs=50, learning_rate=0.1)
# Out:
# Epoch: 001/050 | Train MSE: 0.06 | Train Acc: 70.78% | Valid Acc: 70.85%
# Epoch: 002/050 | Train MSE: 0.04 | Train Acc: 82.86% | Valid Acc: 82.78%
# Epoch: 003/050 | Train MSE: 0.03 | Train Acc: 86.39% | Valid Acc: 86.17%
# Epoch: 004/050 | Train MSE: 0.02 | Train Acc: 88.24% | Valid Acc: 88.03%
# Epoch: 005/050 | Train MSE: 0.02 | Train Acc: 89.19% | Valid Acc: 89.03%
# Epoch: 006/050 | Train MSE: 0.02 | Train Acc: 89.88% | Valid Acc: 89.51%
# Epoch: 007/050 | Train MSE: 0.02 | Train Acc: 90.38% | Valid Acc: 90.30%
# Epoch: 008/050 | Train MSE: 0.02 | Train Acc: 90.80% | Valid Acc: 90.51%
# Epoch: 009/050 | Train MSE: 0.02 | Train Acc: 91.11% | Valid Acc: 90.86%
# Epoch: 010/050 | Train MSE: 0.02 | Train Acc: 91.41% | Valid Acc: 91.18%
# Epoch: 011/050 | Train MSE: 0.02 | Train Acc: 91.60% | Valid Acc: 91.29%
# Epoch: 012/050 | Train MSE: 0.01 | Train Acc: 91.82% | Valid Acc: 91.48%
# Epoch: 013/050 | Train MSE: 0.01 | Train Acc: 92.06% | Valid Acc: 91.77%
# Epoch: 014/050 | Train MSE: 0.01 | Train Acc: 92.29% | Valid Acc: 91.94%
# Epoch: 015/050 | Train MSE: 0.01 | Train Acc: 92.29% | Valid Acc: 92.01%
# Epoch: 016/050 | Train MSE: 0.01 | Train Acc: 92.63% | Valid Acc: 92.23%
# Epoch: 017/050 | Train MSE: 0.01 | Train Acc: 92.73% | Valid Acc: 92.37%
# Epoch: 018/050 | Train MSE: 0.01 | Train Acc: 92.85% | Valid Acc: 92.48%
# Epoch: 019/050 | Train MSE: 0.01 | Train Acc: 93.00% | Valid Acc: 92.67%
# Epoch: 020/050 | Train MSE: 0.01 | Train Acc: 93.06% | Valid Acc: 92.64%
# Epoch: 021/050 | Train MSE: 0.01 | Train Acc: 93.16% | Valid Acc: 92.74%
# Epoch: 022/050 | Train MSE: 0.01 | Train Acc: 93.34% | Valid Acc: 92.89%
# Epoch: 023/050 | Train MSE: 0.01 | Train Acc: 93.44% | Valid Acc: 92.97%
# Epoch: 024/050 | Train MSE: 0.01 | Train Acc: 93.48% | Valid Acc: 93.03%
# Epoch: 025/050 | Train MSE: 0.01 | Train Acc: 93.61% | Valid Acc: 93.14%
# Epoch: 026/050 | Train MSE: 0.01 | Train Acc: 93.70% | Valid Acc: 93.24%
# Epoch: 027/050 | Train MSE: 0.01 | Train Acc: 93.79% | Valid Acc: 93.24%
# Epoch: 028/050 | Train MSE: 0.01 | Train Acc: 93.83% | Valid Acc: 93.24%
# Epoch: 029/050 | Train MSE: 0.01 | Train Acc: 93.94% | Valid Acc: 93.36%
# Epoch: 030/050 | Train MSE: 0.01 | Train Acc: 94.05% | Valid Acc: 93.50%
# Epoch: 031/050 | Train MSE: 0.01 | Train Acc: 94.12% | Valid Acc: 93.53%
# Epoch: 032/050 | Train MSE: 0.01 | Train Acc: 94.17% | Valid Acc: 93.54%
# Epoch: 033/050 | Train MSE: 0.01 | Train Acc: 94.27% | Valid Acc: 93.67%
# Epoch: 034/050 | Train MSE: 0.01 | Train Acc: 94.33% | Valid Acc: 93.61%
# Epoch: 035/050 | Train MSE: 0.01 | Train Acc: 94.43% | Valid Acc: 93.73%
# Epoch: 036/050 | Train MSE: 0.01 | Train Acc: 94.48% | Valid Acc: 93.75%
# Epoch: 037/050 | Train MSE: 0.01 | Train Acc: 94.55% | Valid Acc: 93.80%
# Epoch: 038/050 | Train MSE: 0.01 | Train Acc: 94.59% | Valid Acc: 93.84%
# Epoch: 039/050 | Train MSE: 0.01 | Train Acc: 94.73% | Valid Acc: 93.82%
# Epoch: 040/050 | Train MSE: 0.01 | Train Acc: 94.68% | Valid Acc: 93.86%
# Epoch: 041/050 | Train MSE: 0.01 | Train Acc: 94.77% | Valid Acc: 93.93%
# Epoch: 042/050 | Train MSE: 0.01 | Train Acc: 94.81% | Valid Acc: 93.99%
# Epoch: 043/050 | Train MSE: 0.01 | Train Acc: 94.81% | Valid Acc: 93.96%
# Epoch: 044/050 | Train MSE: 0.01 | Train Acc: 94.89% | Valid Acc: 94.12%
# Epoch: 045/050 | Train MSE: 0.01 | Train Acc: 94.94% | Valid Acc: 94.11%
# Epoch: 046/050 | Train MSE: 0.01 | Train Acc: 95.01% | Valid Acc: 94.19%
# Epoch: 047/050 | Train MSE: 0.01 | Train Acc: 95.00% | Valid Acc: 94.16%
# Epoch: 048/050 | Train MSE: 0.01 | Train Acc: 95.07% | Valid Acc: 94.24%
# Epoch: 049/050 | Train MSE: 0.01 | Train Acc: 95.04% | Valid Acc: 94.24%
# Epoch: 050/050 | Train MSE: 0.01 | Train Acc: 95.16% | Valid Acc: 94.33%

# %% [markdown]
# ## Evaluating the neural network performance

# %%
plt.plot(range(len(epoch_loss)), epoch_loss)
plt.ylabel('Mean squared error')
plt.xlabel('Epoch')
#plt.savefig('figures/11_07.png', dpi=300)
plt.show()

# %%
plt.plot(range(len(epoch_train_acc)), epoch_train_acc,
         label='Training')
plt.plot(range(len(epoch_valid_acc)), epoch_valid_acc,
         label='Validation')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(loc='lower right')
#plt.savefig('figures/11_08.png', dpi=300)
plt.show()

# %%
test_mse, test_acc = compute_mse_and_acc(model, X_test, y_test)
print(f'Test accuracy: {test_acc*100:.2f}%')
# Out:
# Test accuracy: 94.02%

# %% [markdown]
# Plot failure cases:

# %%
X_test_subset = X_test[:1000, :]
y_test_subset = y_test[:1000]

_, probas = model.forward(X_test_subset)
test_pred = np.argmax(probas, axis=1)

misclassified_images = X_test_subset[y_test_subset != test_pred][:25]
misclassified_labels = test_pred[y_test_subset != test_pred][:25]
correct_labels = y_test_subset[y_test_subset != test_pred][:25]

# %%
fig, ax = plt.subplots(nrows=5, ncols=5, 
                       sharex=True, sharey=True, figsize=(8, 8))
ax = ax.flatten()
for i in range(25):
    img = misclassified_images[i].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys', interpolation='nearest')
    ax[i].set_title(f'{i+1}) '
                    f'True: {correct_labels[i]}\n'
                    f' Predicted: {misclassified_labels[i]}')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
#plt.savefig('figures/11_09.png', dpi=300)
plt.show()

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## Implementing a multi-layer perceptron (2 layer)

# %%
import numpy as np

# %%
##########################
### MODEL
##########################

def sigmoid(z):                                        
    return 1. / (1. + np.exp(-z))


def int_to_onehot(y, num_labels):

    ary = np.zeros((y.shape[0], num_labels))
    for i, val in enumerate(y):
        ary[i, val] = 1

    return ary


class NeuralNet2MLP:

    def __init__(self, num_features, num_hidden1, num_hidden2, num_classes, random_seed=123):
        super().__init__()
        
        self.num_classes = num_classes
        
        # hidden1
        rng = np.random.RandomState(random_seed)
        
        self.weight_h1 = rng.normal(
            loc=0.0, scale=0.1, size=(num_hidden1, num_features))
        self.bias_h1 = np.zeros(num_hidden1)

        # hidden2
        rng = np.random.RandomState(random_seed)
        
        self.weight_h2 = rng.normal(
            loc=0.0, scale=0.1, size=(num_hidden2, num_hidden1))
        self.bias_h2 = np.zeros(num_hidden2)
        
        # output
        self.weight_out = rng.normal(
            loc=0.0, scale=0.1, size=(num_classes, num_hidden2))
        self.bias_out = np.zeros(num_classes)
        
    def forward(self, x):
        # Hidden layer 1
        # input dim: [n_examples, n_features] dot [n_hidden1, n_features].T
        # output dim: [n_examples, n_hidden1]
        z_h1 = np.dot(x, self.weight_h1.T) + self.bias_h1
        a_h1 = sigmoid(z_h1)

        # Hidden layer 2
        # input dim: [n_examples, n_hidden1] dot [n_hidden2, n_hidden1].T
        # output dim: [n_examples, n_hidden2]
        z_h2 = np.dot(a_h1, self.weight_h2.T) + self.bias_h2
        a_h2 = sigmoid(z_h2)

        # Output layer
        # input dim: [n_examples, n_hidden2] dot [n_classes, n_hidden2].T
        # output dim: [n_examples, n_classes]
        z_out = np.dot(a_h2, self.weight_out.T) + self.bias_out
        a_out = sigmoid(z_out)
        return a_h1, a_h2, a_out

    def backward(self, x, a_h1, a_h2, a_out, y):  
    
        #########################
        ### Output layer weights
        #########################
        
        # onehot encoding
        y_onehot = int_to_onehot(y, self.num_classes)

        # Part 1: dLoss/dOutWeights
        ## = dLoss/dOutAct * dOutAct/dOutNet * dOutNet/dOutWeight
        ## where DeltaOut = dLoss/dOutAct * dOutAct/dOutNet
        ## for convenient re-use
        
        # input/output dim: [n_examples, n_classes]
        d_loss__d_a_out = 2.*(a_out - y_onehot) / y.shape[0]

        # input/output dim: [n_examples, n_classes]
        d_a_out__d_z_out = a_out * (1. - a_out) # sigmoid derivative

        # output dim: [n_examples, n_classes]
        delta_out = d_loss__d_a_out * d_a_out__d_z_out # "delta (rule) placeholder"

        # gradient for output weights
        
        # [n_examples, n_hidden2]
        d_z_out__dw_out = a_h2
        
        # input dim: [n_classes, n_examples] dot [n_examples, n_hidden2]
        # output dim: [n_classes, n_hidden2]
        d_loss__dw_out = np.dot(delta_out.T, d_z_out__dw_out)
        d_loss__db_out = np.sum(delta_out, axis=0)
        

        #################################        
        # Part 2: dLoss/dHidden2Weights
        ## = DeltaOut * dOutNet/dHidden2Act * dHidden2Act/dHidden2Net * dHidden2Net/dWeight
        
        # [n_classes, n_hidden]
        d_z_out__a_h2 = self.weight_out
        
        # output dim: [n_examples, n_hidden2]
        d_loss__a_h2 = np.dot(delta_out, d_z_out__a_h2)
        
        # [n_hidden1, n_hidden2]
        d_a_h__d_z_h2 = a_h2 * (1. - a_h2) # sigmoid derivative
        
        # [n_examples, n_features]
        d_z_h__d_w_h2 = a_h1
        
        # output dim: [n_hidden, n_features]
        d_loss__d_w_h2 = np.dot((d_loss__a_h2 * d_a_h__d_z_h2).T, d_z_h__d_w_h2)
        d_loss__d_b_h2 = np.sum((d_loss__a_h2 * d_a_h__d_z_h2), axis=0)

        #################################        
        # Part 3: dLoss/dHiddenWeights
        ## = DeltaOut * dOutNet/dHiddenAct * dHiddenAct/dHiddenNet * dHiddenNet/dWeight
        
        # [n_hidden2, n_hidden1]
        d_z_out__a_h1 = self.weight_h2
        
        # output dim: [n_examples, n_hidden]
        d_loss__a_h1 = np.dot(d_loss__a_h2, d_z_out__a_h1)
        
        # [n_examples, n_hidden1]
        d_a_h__d_z_h1 = a_h1 * (1. - a_h1) # sigmoid derivative
        
        # [n_examples, n_features]
        d_z_h__d_w_h1 = x
        
        # output dim: [n_hidden, n_features]
        d_loss__d_w_h1 = np.dot((d_loss__a_h1 * d_a_h__d_z_h1).T, d_z_h__d_w_h1)
        d_loss__d_b_h1 = np.sum((d_loss__a_h1 * d_a_h__d_z_h1), axis=0)

        return (d_loss__dw_out, d_loss__db_out, 
                d_loss__d_w_h1, d_loss__d_b_h1, d_loss__d_w_h2, d_loss__d_b_h2)

# %%
model = NeuralNet2MLP(num_features=28*28, num_hidden1=50, num_hidden2=40, num_classes=10)

# %% [markdown]
# ## Coding the neural network training loop (2 layer)

# %% [markdown]
# Defining data loaders:

# %%
import numpy as np

num_epochs = 50
minibatch_size = 100


def minibatch_generator(X, y, minibatch_size):
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)

    for start_idx in range(0, indices.shape[0] - minibatch_size 
                           + 1, minibatch_size):
        batch_idx = indices[start_idx:start_idx + minibatch_size]
        
        yield X[batch_idx], y[batch_idx]

        
# iterate over training epochs
for i in range(num_epochs):

    # iterate over minibatches
    minibatch_gen = minibatch_generator(
        X_train, y_train, minibatch_size)
    
    for X_train_mini, y_train_mini in minibatch_gen:

        break
        
    break
    
print(X_train_mini.shape)
print(y_train_mini.shape)
# Out:
# (100, 784)
# (100,)

# %% [markdown]
# Defining a function to compute the loss and accuracy

# %%
def mse_loss(targets, probas, num_labels=10):
    onehot_targets = int_to_onehot(targets, num_labels=num_labels)
    return np.mean((onehot_targets - probas)**2)


def accuracy(targets, predicted_labels):
    return np.mean(predicted_labels == targets) 

_1, _2, probas = model.forward(X_valid)
mse = mse_loss(y_valid, probas)

predicted_labels = np.argmax(probas, axis=1)
acc = accuracy(y_valid, predicted_labels)

print(f'Initial validation MSE: {mse:.1f}')
print(f'Initial validation accuracy: {acc*100:.1f}%')
# Out:
# Initial validation MSE: 0.3
# Initial validation accuracy: 9.8%

# %%
import numpy as np
from sklearn import metrics
def compute_mse_and_acc(nnet, X, y, num_labels=10, minibatch_size=100):
    mse, correct_pred, num_examples = 0., 0, 0
    minibatch_gen = minibatch_generator(X, y, minibatch_size)
    for i, (features, targets) in enumerate(minibatch_gen):

        _1, _2, probas = nnet.forward(features)
        predicted_labels = np.argmax(probas, axis=1)
        
        onehot_targets = int_to_onehot(targets, num_labels=num_labels)
        loss = np.mean((onehot_targets - probas)**2)
        correct_pred += (predicted_labels == targets).sum()
        
        num_examples += targets.shape[0]
        mse += loss

        if i == 0:
          total_predicted_labels = predicted_labels
        else:
          total_predicted_labels = np.append(total_predicted_labels, predicted_labels)

    mse = mse/i
    acc = correct_pred/num_examples

    fpr, tpr, thresholds = metrics.roc_curve(y, total_predicted_labels, pos_label=2)
    auc = metrics.auc(fpr, tpr)
    return mse, acc, auc, fpr, tpr

# %%
mse, acc, auc, fpr, tpr = compute_mse_and_acc(model, X_valid, y_valid)
print(f'Initial valid MSE: {mse:.1f}')
print(f'Initial valid accuracy: {acc*100:.1f}%')
# Out:
# Initial valid MSE: 0.3
# Initial valid accuracy: 9.8%

# %%
def train(model, X_train, y_train, X_valid, y_valid, num_epochs,
          learning_rate=0.1):
    
    epoch_loss = []
    epoch_train_acc = []
    epoch_valid_acc = []
    
    for e in range(num_epochs):

        # iterate over minibatches
        minibatch_gen = minibatch_generator(
            X_train, y_train, minibatch_size)

        for X_train_mini, y_train_mini in minibatch_gen:
            
            #### Compute outputs ####
            a_h1, a_h2, a_out = model.forward(X_train_mini)

            #### Compute gradients ####
            d_loss__d_w_out, d_loss__d_b_out, d_loss__d_w_h1, d_loss__d_b_h1, d_loss__d_w_h2, d_loss__d_b_h2 = \
                model.backward(X_train_mini, a_h1, a_h2, a_out, y_train_mini)

            #### Update weights ####
            model.weight_h1 -= learning_rate * d_loss__d_w_h1
            model.bias_h1 -= learning_rate * d_loss__d_b_h1
            model.weight_h2 -= learning_rate * d_loss__d_w_h2
            model.bias_h2 -= learning_rate * d_loss__d_b_h2
            model.weight_out -= learning_rate * d_loss__d_w_out
            model.bias_out -= learning_rate * d_loss__d_b_out
        
        #### Epoch Logging ####        
        train_mse, train_acc, train_auc, fpr, tpr = compute_mse_and_acc(model, X_train, y_train)
        valid_mse, valid_acc, valid_auc, fpr, tpr = compute_mse_and_acc(model, X_valid, y_valid)
        train_acc, valid_acc = train_acc*100, valid_acc*100
        epoch_train_acc.append(train_acc)
        epoch_valid_acc.append(valid_acc)
        epoch_loss.append(train_mse)
        print(f'Epoch: {e+1:03d}/{num_epochs:03d} '
              f'| Train MSE: {train_mse:.2f} '
              f'| Train Acc: {train_acc:.2f}% '
              f'| Valid Acc: {valid_acc:.2f}%')

    return epoch_loss, epoch_train_acc, epoch_valid_acc

# %%
np.random.seed(123) # for the training set shuffling

epoch_loss, epoch_train_acc, epoch_valid_acc = train(
    model, X_train, y_train, X_valid, y_valid,
    num_epochs=50, learning_rate=0.1)
# Out:
# Epoch: 001/050 | Train MSE: 0.09 | Train Acc: 11.25% | Valid Acc: 11.26%
# Epoch: 002/050 | Train MSE: 0.09 | Train Acc: 25.02% | Valid Acc: 24.97%
# Epoch: 003/050 | Train MSE: 0.08 | Train Acc: 36.22% | Valid Acc: 36.22%
# Epoch: 004/050 | Train MSE: 0.06 | Train Acc: 52.41% | Valid Acc: 52.53%
# Epoch: 005/050 | Train MSE: 0.05 | Train Acc: 66.72% | Valid Acc: 67.07%
# Epoch: 006/050 | Train MSE: 0.04 | Train Acc: 75.73% | Valid Acc: 75.19%
# Epoch: 007/050 | Train MSE: 0.04 | Train Acc: 84.35% | Valid Acc: 84.21%
# Epoch: 008/050 | Train MSE: 0.03 | Train Acc: 87.20% | Valid Acc: 86.89%
# Epoch: 009/050 | Train MSE: 0.02 | Train Acc: 88.89% | Valid Acc: 88.61%
# Epoch: 010/050 | Train MSE: 0.02 | Train Acc: 89.78% | Valid Acc: 89.53%
# Epoch: 011/050 | Train MSE: 0.02 | Train Acc: 90.36% | Valid Acc: 89.99%
# Epoch: 012/050 | Train MSE: 0.02 | Train Acc: 90.62% | Valid Acc: 90.28%
# Epoch: 013/050 | Train MSE: 0.02 | Train Acc: 91.25% | Valid Acc: 90.79%
# Epoch: 014/050 | Train MSE: 0.02 | Train Acc: 91.55% | Valid Acc: 91.09%
# Epoch: 015/050 | Train MSE: 0.01 | Train Acc: 91.87% | Valid Acc: 91.42%
# Epoch: 016/050 | Train MSE: 0.01 | Train Acc: 92.25% | Valid Acc: 91.72%
# Epoch: 017/050 | Train MSE: 0.01 | Train Acc: 92.61% | Valid Acc: 92.01%
# Epoch: 018/050 | Train MSE: 0.01 | Train Acc: 92.72% | Valid Acc: 92.08%
# Epoch: 019/050 | Train MSE: 0.01 | Train Acc: 93.00% | Valid Acc: 92.33%
# Epoch: 020/050 | Train MSE: 0.01 | Train Acc: 93.10% | Valid Acc: 92.36%
# Epoch: 021/050 | Train MSE: 0.01 | Train Acc: 93.54% | Valid Acc: 92.62%
# Epoch: 022/050 | Train MSE: 0.01 | Train Acc: 93.58% | Valid Acc: 92.81%
# Epoch: 023/050 | Train MSE: 0.01 | Train Acc: 93.83% | Valid Acc: 92.99%
# Epoch: 024/050 | Train MSE: 0.01 | Train Acc: 94.11% | Valid Acc: 93.14%
# Epoch: 025/050 | Train MSE: 0.01 | Train Acc: 94.27% | Valid Acc: 93.42%
# Epoch: 026/050 | Train MSE: 0.01 | Train Acc: 94.35% | Valid Acc: 93.40%
# Epoch: 027/050 | Train MSE: 0.01 | Train Acc: 94.34% | Valid Acc: 93.34%
# Epoch: 028/050 | Train MSE: 0.01 | Train Acc: 94.68% | Valid Acc: 93.72%
# Epoch: 029/050 | Train MSE: 0.01 | Train Acc: 94.84% | Valid Acc: 93.78%
# Epoch: 030/050 | Train MSE: 0.01 | Train Acc: 94.88% | Valid Acc: 93.89%
# Epoch: 031/050 | Train MSE: 0.01 | Train Acc: 95.08% | Valid Acc: 94.20%
# Epoch: 032/050 | Train MSE: 0.01 | Train Acc: 95.24% | Valid Acc: 94.19%
# Epoch: 033/050 | Train MSE: 0.01 | Train Acc: 95.39% | Valid Acc: 94.24%
# Epoch: 034/050 | Train MSE: 0.01 | Train Acc: 95.41% | Valid Acc: 94.12%
# Epoch: 035/050 | Train MSE: 0.01 | Train Acc: 95.45% | Valid Acc: 94.36%
# Epoch: 036/050 | Train MSE: 0.01 | Train Acc: 95.72% | Valid Acc: 94.55%
# Epoch: 037/050 | Train MSE: 0.01 | Train Acc: 95.78% | Valid Acc: 94.51%
# Epoch: 038/050 | Train MSE: 0.01 | Train Acc: 95.86% | Valid Acc: 94.72%
# Epoch: 039/050 | Train MSE: 0.01 | Train Acc: 95.84% | Valid Acc: 94.59%
# Epoch: 040/050 | Train MSE: 0.01 | Train Acc: 96.00% | Valid Acc: 94.78%
# Epoch: 041/050 | Train MSE: 0.01 | Train Acc: 96.15% | Valid Acc: 94.82%
# Epoch: 042/050 | Train MSE: 0.01 | Train Acc: 96.19% | Valid Acc: 94.81%
# Epoch: 043/050 | Train MSE: 0.01 | Train Acc: 96.31% | Valid Acc: 95.00%
# Epoch: 044/050 | Train MSE: 0.01 | Train Acc: 96.28% | Valid Acc: 94.97%
# Epoch: 045/050 | Train MSE: 0.01 | Train Acc: 96.45% | Valid Acc: 95.04%
# Epoch: 046/050 | Train MSE: 0.01 | Train Acc: 96.41% | Valid Acc: 95.07%
# Epoch: 047/050 | Train MSE: 0.01 | Train Acc: 96.57% | Valid Acc: 95.17%
# Epoch: 048/050 | Train MSE: 0.01 | Train Acc: 96.63% | Valid Acc: 95.23%
# Epoch: 049/050 | Train MSE: 0.01 | Train Acc: 96.64% | Valid Acc: 95.13%
# Epoch: 050/050 | Train MSE: 0.01 | Train Acc: 96.79% | Valid Acc: 95.26%

# %% [markdown]
# ## Evaluating the neural network performance (2 layer)

# %%
plt.plot(range(len(epoch_loss)), epoch_loss)
plt.ylabel('Mean squared error')
plt.xlabel('Epoch')
#plt.savefig('figures/11_07.png', dpi=300)
plt.show()

# %%
plt.plot(range(len(epoch_train_acc)), epoch_train_acc,
         label='Training')
plt.plot(range(len(epoch_valid_acc)), epoch_valid_acc,
         label='Validation')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(loc='lower right')
#plt.savefig('figures/11_08.png', dpi=300)
plt.show()

# %%
test_mse, test_acc, test_auc, fpr, tpr = compute_mse_and_acc(model, X_test, y_test)
print(f'Test accuracy: {test_acc*100:.2f}%')
print(f'Test auc: {test_auc*100:.2f}%')
# Out:
# Test accuracy: 95.17%
# Test auc: 50.47%

# %% [markdown]
# Plot failure cases:

# %%
X_test_subset = X_test[:1000, :]
y_test_subset = y_test[:1000]

_1, _2, probas = model.forward(X_test_subset)
test_pred = np.argmax(probas, axis=1)

misclassified_images = X_test_subset[y_test_subset != test_pred][:25]
misclassified_labels = test_pred[y_test_subset != test_pred][:25]
correct_labels = y_test_subset[y_test_subset != test_pred][:25]

# %%
fig, ax = plt.subplots(nrows=5, ncols=5, 
                       sharex=True, sharey=True, figsize=(8, 8))
ax = ax.flatten()
for i in range(25):
    img = misclassified_images[i].reshape(28, 28)
    ax[i].imshow(img, cmap='Greys', interpolation='nearest')
    ax[i].set_title(f'{i+1}) '
                    f'True: {correct_labels[i]}\n'
                    f' Predicted: {misclassified_labels[i]}')

ax[0].set_xticks([])
ax[0].set_yticks([])
plt.tight_layout()
#plt.savefig('figures/11_09.png', dpi=300)
plt.show()

# %% [markdown]
# <br>
# <br>

# %%
plt.figure()
lw = 2
plt.plot(
    fpr,
    tpr,
    color="darkorange",
    lw=lw,
    label="ROC curve (area = %0.2f)" % test_auc,
)
plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic example")
plt.legend(loc="lower right")
plt.show()
